# %% [markdown]
# ### Declare Dependencies

# %%
from bs4 import BeautifulSoup
from splinter import Browser
import pandas as pd
import requests

# %% [markdown]
# ### Declare in Memory

# %%
# Drivers`s Path
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# %% [markdown]
# ### NCAA |  Game Schedule

# %%
###

# %%
###

# %% [markdown]
# ### NCAA |  Scoreboard

# %%
# # NCAA scoreboard url through splinter module , hardcode "year", "Month", "Day" and team
# score_url = 'https://www.ncaa.com/game/lacrosse-women/d1/2019/05/02/army-navy/boxscore'
# browser.visit(url)

# %%
#     # Go to NCAA ScoreBox url 
# score_url = 'https://www.ncaa.com/game/lacrosse-women/d1/2019/05/02/army-navy/boxscore/'
#     # Create a Beautiful Soup object
# ncaa_score = pd.read_html(score_url)
#     # Find the mars facts DataFrame in the list of DataFrames as assign it to `ncaa_df`
# ncaa_df = ncaa_score[0]
# ncaa_df.columns = ['Description','Value']
#     # Set the index to the `Description` column without row indexing
# ncaa_df.set_index('Description', inplace=True)
#     # Save html code to folder Assets
# ncaa_df.to_html()
# data = ncaa_df.to_dict(orient='records')  
#     # Print out in the window
# ncaa_df

# %%
# Go to Mars Weather Twitter through splinter module
score_url = 'https://www.ncaa.com/game/lacrosse-women/d1/2019/05/02/army-navy/boxscore'
browser.visit(score_url)

# %%
  # HTML Object 
html_score = browser.html
  # Create a Beautiful Soup object
soup = BeautifulSoup(html_score, 'html.parser')
  # Find all elements that contain scores
latest_scores = soup.find_all('div', class_='gamecenter-tab-boxscore')
latest_scores
  # Retrieve all elements that contain news title in the specified range
#   # Look for entries that display weather related words to exclude non weather related tweets 
# for tweet in latest_tweets: 
#     weather_tweet = tweet.find('p').text
#     if 'Sol' and 'pressure' in weather_tweet:
#         print(weather_tweet)
#         break
#     else: 
#         passboxscore-table boxscore-table_player_visitor
# Out:
# [<div class="gamecenter-tab-boxscore"><div class="boxscore-team-selector"><div class="boxscore-team-selector-team awayTeam-bg-primary_color homeTeam-border-primary_color away active">
#  Army
#  </div>
#  <div class="boxscore-team-selector-team homeTeam-bg-primary_color awayTeam-border-primary_color home">
#  Navy
#  </div>
#  </div><div class="boxscore-table-collection"><div class="boxscore-table boxscore-table_player_visitor"><table>
#  <thead>
#  <tr class="header">
#  <th>
#  No
#  </th>
#  <th>
#  Name
#  </th>
#  <th>
#  POS
#  </th>
#  <th>
#  G
#  </th>
#  <th>
#  A
#  </th>
#  <th>
#  SH
#  </th>
#  <th>
#  SOG
#  </th>
#  <th>
#  GB
#  </th>
#  </tr>
#  </thead>
#  <tbody>
#  <tr>
#  <td class="jersey-number">
#  10
#  </td>
#  <td>
#  SAMANTHA STEWART
#  </td>
#  <td>
#  M
#  </td>
#  <td>
#  1
#  </td>
#  <td>
#  2
#  </td>
#  <td>
#  4
#  </td>
#  <td>
#  3
#  </td>
#  <td>
#  2
#  </td>
#  </tr>
#  <tr>
#  <td class="jersey-number">
#  13
#  </td>
#  <td>
# ...
